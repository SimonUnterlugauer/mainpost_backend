# %%
import os
import warnings
import sys

import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import ElasticNet
from urllib.parse import urlparse
import mlflow
from mlflow.models import infer_signature
import mlflow.sklearn

import logging

# %%
csv_url = (
        "http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv"
    )
data = pd.read_csv(csv_url, sep=";")
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
# Wine Quality Sample
def train(in_alpha, in_l1_ratio):
  

    logging.basicConfig(level=logging.WARN)
    logger = logging.getLogger(__name__)

    def eval_metrics(actual, pred):
        rmse = np.sqrt(mean_squared_error(actual, pred))
        mae = mean_absolute_error(actual, pred)
        r2 = r2_score(actual, pred)
        return rmse, mae, r2

    warnings.filterwarnings("ignore")
    np.random.seed(40)

    # Split the data into training and test sets. (0.75, 0.25) split.
    train, test = train_test_split(data)

    # The predicted column is "quality" which is a scalar from [3, 9]
    train_x = train.drop(["quality"], axis=1)
    test_x = test.drop(["quality"], axis=1)
    train_y = train[["quality"]]
    test_y = test[["quality"]]

    # Set default values if no alpha is provided
    if float(in_alpha) is None:
        alpha = 0.5
    else:
        alpha = float(in_alpha)

    # Set default values if no l1_ratio is provided
    if float(in_l1_ratio) is None:
        l1_ratio = 0.5
    else:
        l1_ratio = float(in_l1_ratio)
        # Useful for multiple runs (only doing one run in this sample notebook)
    with mlflow.start_run():
        # Execute ElasticNet
        lr = ElasticNet(alpha=alpha, l1_ratio=l1_ratio, random_state=42)
        lr.fit(train_x, train_y)

        # Evaluate Metrics
        predicted_qualities = lr.predict(test_x)
        (rmse, mae, r2) = eval_metrics(test_y, predicted_qualities)

        # Print out metrics
        print("Elasticnet model (alpha=%f, l1_ratio=%f):" % (alpha, l1_ratio))
        print("  RMSE: %s" % rmse)
        print("  MAE: %s" % mae)
        print("  R2: %s" % r2)

        # Infer model signature
        predictions = lr.predict(train_x)
        signature = infer_signature(train_x, predictions)

        # Log parameter, metrics, and model to MLflow
        mlflow.log_param("alpha", alpha)
        mlflow.log_param("l1_ratio", l1_ratio)
        mlflow.log_metric("rmse", rmse)
        mlflow.log_metric("r2", r2)
        mlflow.log_metric("mae", mae)

        mlflow.sklearn.log_model(lr, "model", signature=signature)

# %%
train(0.5, 0.5)
# Out:
# Elasticnet model (alpha=0.500000, l1_ratio=0.500000):
#   RMSE: 0.7931640229276851
#   MAE: 0.6271946374319586
#   R2: 0.10862644997792614
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 train(0.5, 0.5)
#
# Cell In[5], line 89, in train(in_alpha, in_l1_ratio)
#      86 mlflow.log_metric("r2", r2)
#      87 mlflow.log_metric("mae", mae)
# ---> 89 mlflow.sklearn.log_model(lr, "model", signature=signature)
#
# File c:\Users\jakob\AppData\Local\Programs\Python\Python39\lib\site-packages\mlflow\sklearn\__init__.py:407, in log_model(sk_model, artifact_path, conda_env, code_paths, serialization_format, registered_model_name, signature, input_example, await_registration_for, pip_requirements, extra_pip_requirements, pyfunc_predict_fn, metadata)
#     327 @format_docstring(LOG_MODEL_PARAM_DOCS.format(package_name="scikit-learn"))
#     328 def log_model(
#     329     sk_model,
#    (...)
#     341     metadata=None,
#     342 ):
#     343     """
#     344     Log a scikit-learn model as an MLflow artifact for the current run. Produces an MLflow Model
#     345     containing the following flavors:
#    (...)
#     405
#     406     """
# --> 407     return Model.log(
#     408         artifact_path=artifact_path,
#     409         flavor=mlflow.sklearn,
#     410         sk_model=sk_model,
#     411         conda_env=conda_env,
#     412         code_paths=code_paths,
#     413         serialization_format=serialization_format,
#     414         registered_model_name=registered_model_name,
#     415         signature=signature,
#     416         input_example=input_example,
#     417         await_registration_for=await_registration_for,
#     418         pip_requirements=pip_requirements,
#     419         extra_pip_requirements=extra_pip_requirements,
#     420         pyfunc_predict_fn=pyfunc_predict_fn,
#     421         metadata=metadata,
#     422     )
#
# File c:\Users\jakob\AppData\Local\Programs\Python\Python39\lib\site-packages\mlflow\models\model.py:573, in Model.log(cls, artifact_path, flavor, registered_model_name, await_registration_for, metadata, **kwargs)
#     571     _logger.warning(_LOG_MODEL_MISSING_SIGNATURE_WARNING)
#     572 flavor.save_model(path=local_path, mlflow_model=mlflow_model, **kwargs)
# --> 573 mlflow.tracking.fluent.log_artifacts(local_path, mlflow_model.artifact_path)
#     574 try:
#     575     mlflow.tracking.fluent._record_logged_model(mlflow_model)
#
# File c:\Users\jakob\AppData\Local\Programs\Python\Python39\lib\site-packages\mlflow\tracking\fluent.py:911, in log_artifacts(local_dir, artifact_path)
#     881 """
#     882 Log all the contents of a local directory as artifacts of the run. If no run is active,
#     883 this method will create a new active run.
#    (...)
#     908         mlflow.log_artifacts("data", artifact_path="states")
#     909 """
#     910 run_id = _get_or_start_run().info.run_id
# --> 911 MlflowClient().log_artifacts(run_id, local_dir, artifact_path)
#
# File c:\Users\jakob\AppData\Local\Programs\Python\Python39\lib\site-packages\mlflow\tracking\client.py:1137, in MlflowClient.log_artifacts(self, run_id, local_dir, artifact_path)
#    1093 def log_artifacts(
#    1094     self, run_id: str, local_dir: str, artifact_path: Optional[str] = None
#    1095 ) -> None:
#    1096     """
#    1097     Write a directory of files to the remote ``artifact_uri``.
#    1098
#    (...)
#    1135         is_dir: True
#    1136     """
# -> 1137     self._tracking_client.log_artifacts(run_id, local_dir, artifact_path)
#
# File c:\Users\jakob\AppData\Local\Programs\Python\Python39\lib\site-packages\mlflow\tracking\_tracking_service\client.py:465, in TrackingServiceClient.log_artifacts(self, run_id, local_dir, artifact_path)
#     458 def log_artifacts(self, run_id, local_dir, artifact_path=None):
#     459     """
#     460     Write a directory of files to the remote ``artifact_uri``.
#     461
#     462     :param local_dir: Path to the directory of files to write.
#     463     :param artifact_path: If provided, the directory in ``artifact_uri`` to write to.
#     464     """
# --> 465     self._get_artifact_repo(run_id).log_artifacts(local_dir, artifact_path)
#
# File c:\Users\jakob\AppData\Local\Programs\Python\Python39\lib\site-packages\mlflow\tracking\_tracking_service\client.py:433, in TrackingServiceClient._get_artifact_repo(self, run_id)
#     429 run = self.get_run(run_id)
#     430 artifact_uri = add_databricks_profile_info_to_artifact_uri(
#     431     run.info.artifact_uri, self.tracking_uri
#     432 )
# --> 433 artifact_repo = get_artifact_repository(artifact_uri)
#     434 # Cache the artifact repo to avoid a future network call, removing the oldest
#     435 # entry in the cache if there are too many elements
#     436 if len(TrackingServiceClient._artifact_repos_cache) > 1024:
#
# File c:\Users\jakob\AppData\Local\Programs\Python\Python39\lib\site-packages\mlflow\store\artifact\artifact_repository_registry.py:114, in get_artifact_repository(artifact_uri)
#     104 def get_artifact_repository(artifact_uri):
#     105     """Get an artifact repository from the registry based on the scheme of artifact_uri
#     106
#     107     :param artifact_uri: The artifact store URI. This URI is used to select which artifact
#    (...)
#     112              requirements.
#     113     """
# --> 114     return _artifact_repository_registry.get_artifact_repository(artifact_uri)
#
# File c:\Users\jakob\AppData\Local\Programs\Python\Python39\lib\site-packages\mlflow\store\artifact\artifact_repository_registry.py:72, in ArtifactRepositoryRegistry.get_artifact_repository(self, artifact_uri)
#      65 if repository is None:
#      66     raise MlflowException(
#      67         "Could not find a registered artifact repository for: {}. "
#      68         "Currently registered schemes are: {}".format(
#      69             artifact_uri, list(self._registry.keys())
#      70         )
#      71     )
# ---> 72 return repository(artifact_uri)
#
# File c:\Users\jakob\AppData\Local\Programs\Python\Python39\lib\site-packages\mlflow\store\artifact\mlflow_artifacts_repo.py:45, in MlflowArtifactsRepository.__init__(self, artifact_uri)
#      44 def __init__(self, artifact_uri):
# ---> 45     super().__init__(self.resolve_uri(artifact_uri, get_tracking_uri()))
#
# File c:\Users\jakob\AppData\Local\Programs\Python\Python39\lib\site-packages\mlflow\store\artifact\mlflow_artifacts_repo.py:59, in MlflowArtifactsRepository.resolve_uri(cls, artifact_uri, tracking_uri)
#      56 _validate_port_mapped_to_hostname(uri_parse)
#      58 # Check that tracking uri is http or https
# ---> 59 _validate_uri_scheme(track_parse.scheme)
#      61 if uri_parse.path == "/":  # root directory; build simple path
#      62     resolved = f"{base_url}{uri_parse.path}"
#
# File c:\Users\jakob\AppData\Local\Programs\Python\Python39\lib\site-packages\mlflow\store\artifact\mlflow_artifacts_repo.py:35, in _validate_uri_scheme(scheme)
#      33 allowable_schemes = {"http", "https"}
#      34 if scheme not in allowable_schemes:
# ---> 35     raise MlflowException(
#      36         f"The configured tracking uri scheme: '{scheme}' is invalid for use with the proxy "
#      37         f"mlflow-artifact scheme. The allowed tracking schemes are: {allowable_schemes}"
#      38     )
#
# MlflowException: The configured tracking uri scheme: 'file' is invalid for use with the proxy mlflow-artifact scheme. The allowed tracking schemes are: {'https', 'http'}
