# %%
import pandas as pd
from src.routes import basic

# %%
df = pd.read_csv('./data/processed/absences_daily.csv')

# %%
basic.df_to_json(df)
# Out:
# [{'date': '2020-01-02', 'count': 2},
#  {'date': '2020-01-03', 'count': 2},
#  {'date': '2020-01-04', 'count': 2},
#  {'date': '2020-01-15', 'count': 4},
#  {'date': '2020-01-16', 'count': 4},
#  {'date': '2020-01-17', 'count': 7},
#  {'date': '2020-01-18', 'count': 17},
#  {'date': '2020-01-19', 'count': 14},
#  {'date': '2020-01-20', 'count': 17},
#  {'date': '2020-01-21', 'count': 24},
#  {'date': '2020-01-22', 'count': 17},
#  {'date': '2020-01-23', 'count': 21},
#  {'date': '2020-01-24', 'count': 24},
#  {'date': '2020-01-25', 'count': 40},
#  {'date': '2020-01-26', 'count': 11},
#  {'date': '2020-01-27', 'count': 28},
#  {'date': '2020-01-28', 'count': 42},
#  {'date': '2020-01-29', 'count': 41},
#  {'date': '2020-01-30', 'count': 38},
#  {'date': '2020-01-31', 'count': 49},
#  {'date': '2020-02-01', 'count': 65},
#  {'date': '2020-02-02', 'count': 25},
#  {'date': '2020-02-03', 'count': 50},
#  {'date': '2020-02-04', 'count': 39},
#  {'date': '2020-02-05', 'count': 46},
# ...
